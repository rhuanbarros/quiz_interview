# %%
prompt = (
    "I'm studying Machine Learning and need help to create a comprehensive list of topics and concepts to revise my study. \n"
    "I already have a list of topics of the content that will be present in my final exam of my university with the learning goals for each topic. \n"
    "I need you to work like an experienced teacher that knows everything about machine learning. \n"

    "Your task is to expand the topic list with new sub-sections. \n"
    # "I want to create a type of summary that captures the main concepts about each topic. \n"
    
    # "The content should be comprehensive and show all the content that I should know. You should write important concepts and should explain briefly each topic. \n"
    "The content should be comprehensive and show all the content that I should know. \n"
    
    "I will use it to revise to study. \n"
    
    # "For each group of topics of related subjects, I want you to create a new topic with sub-items called 'Similarities' and another called 'Differences'. \n"
    # "In each one, you should write the most important concepts that are similar and different in the group that I should be aware of in the test, like a summary. \n"

    # " \n"
    " \n\n"
    "Here I will take one of the topics of the list that I need you to expand and I will expand it. \n"
    "Notice that I COPY the original topic and put the expansion in the sub-itens.  \n"
    " \n"
    "# Example of topic expansion \n"
    " \n\n"
    " \n\n"

    """
- Probability & Statistics
    - Metrics and Model Diagnostics
        - Effect Sizes
            - Calculate Cohen's d
                ### 1. **Effect Size Overview**
                * Definition of effect size
                * Importance of effect size in statistics
                * Difference between statistical significance and effect size
                * Types of effect sizes (e.g., Cohen’s d, Pearson’s r, odds ratio, etc.)

                ### 2. **Cohen's d**
                * Definition of Cohen's d
                * Formula for Cohen's d
                    * \( d = \frac{M_1 - M_2}{SD_{pooled}} \)
                * Use cases for Cohen’s d (comparing means between two groups)

                ### 3. **Interpreting Cohen's d**
                * Thresholds for interpretation (Small, Medium, Large effects)
                    * Small effect: \( d = 0.2 \)
                    * Medium effect: \( d = 0.5 \)
                    * Large effect: \( d = 0.8 \)
                * Context-specific interpretation
                * Limitations of using fixed thresholds

                ### 4. **Pooled Standard Deviation**
                * Definition of pooled standard deviation
                * Formula for pooled standard deviation
                    * \( SD_{pooled} = \sqrt{\frac{(n_1 - 1)SD_1^2 + (n_2 - 1)SD_2^2}{n_1 + n_2 - 2}} \)
                * Why use pooled standard deviation in Cohen's d?

                ### 5. **When to Use Cohen's d**
                * Comparison of means between two independent groups
                * T-tests vs. Cohen’s d
                * Use in psychology, education, medicine, etc.

                ### 6. **Other Variants of Cohen's d**
                * Hedges' g (adjustment for small sample sizes)
                * Glass's delta (when standard deviation differs greatly between groups)
                * Cohen’s d for dependent/paired samples

                ### 7. **Practical Examples of Cohen's d**
                * Example of calculating Cohen’s d in a study
                * Interpreting Cohen’s d in published research papers

                ### 8. **Common Misinterpretations of Effect Sizes**
                * Misconceptions around large vs. small effect sizes
                * Confounding variables and their effect on Cohen’s d
                * Overemphasis on effect size without considering practical significance

                ### 9. **Effect Sizes in Meta-Analysis**
                * Aggregating effect sizes across multiple studies
                * Role of Cohen’s d in meta-analysis
                * Adjusting for sample size variability
"""

    
    "# Output format: \n"
    "You should output markdown code so I can copy it. \n"
    
    "# LIST OF TOPICS TO EXPAND\n"
    "\n\n"
)

print(prompt)
# Out:
# I'm studying Machine Learning and need help to create a comprehensive list of topics and concepts to revise my study.
# I already have a list of topics of the content that will be present in my final exam of my university with the learning goals for each topic.
# I need you to work like an experienced teacher that knows everything about machine learning.
# Your task is to expand the topic list with new sub-sections.
# The content should be comprehensive and show all the content that I should know.
# I will use it to revise to study.
#
#
# # Example of topic expansion:
# ### 1. **Effect Size Overview**
# * Definition of effect size
# * Importance of effect size in statistics
# * Difference between statistical significance and effect size
# * Types of effect sizes (e.g., Cohen’s d, Pearson’s r, odds ratio, etc.)
#
# ### 2. **Cohen's d**
# * Definition of Cohen's d
# * Formula for Cohen's d
#     * \( d = rac{M_1 - M_2}{SD_{pooled}} \)
# ...
